# %% [markdown]
# <a href="https://colab.research.google.com/github/Hairul008/Hairul_Prakikum-Pengolahan-Citra-Digital/blob/main/PCD(3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread('/content/Barca.png')
img_real = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
smoothed_image = cv2.blur(img_real, (5, 5))

# %%
plt.subplot(1, 2, 1)
plt.title("Original")
plt.imshow(img_real)

plt.subplot(1, 2, 2)
plt.title("Neighborhood Averaging")
plt.imshow(smoothed_image)
plt.show()

# %%
median_filtered = cv2.medianBlur(img_real, 5)

# %%
plt.subplot(1,2, 1)
plt.title("Original")
plt.imshow(img_real)

plt.subplot(1, 2, 2)
plt.title("Median Blur")
plt.imshow(median_filtered)
plt.show()

# %%
kernel = np.array([[0, -1, 0],[-1, 5, -1], [0, -1, 0]])

#Sharpen the image
high_pass_filtered = cv2.filter2D(img_real, -1, kernel)

# %%
plt.subplot(1,2, 1)
plt.title("Original")
plt.imshow(img_real)

plt.subplot(1, 2, 2)
plt.title(" High-pass Filtering")
plt.imshow(high_pass_filtered)
plt.show()
